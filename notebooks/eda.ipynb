# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
sup_data = pd.read_csv('../data/supplementary_data.csv')
sup_data.head()
# Out:
# /var/folders/cn/x384rbv51ss4zc1t6spzs7_r0000gn/T/ipykernel_95426/2582464920.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   sup_data = pd.read_csv('../data/supplementary_data.csv')
#       game_id  season  week   game_date game_time_eastern home_team_abbr  \
# 0  2023090700    2023     1  09/07/2023          20:20:00             KC
# 1  2023090700    2023     1  09/07/2023          20:20:00             KC
# 2  2023090700    2023     1  09/07/2023          20:20:00             KC
# 3  2023090700    2023     1  09/07/2023          20:20:00             KC
# 4  2023090700    2023     1  09/07/2023          20:20:00             KC
#
#   visitor_team_abbr  play_id  \
# 0               DET     3461
# 1               DET      461
# 2               DET     1940
# 3               DET     1711
# 4               DET     1588
#
#                                     play_description  quarter game_clock  \
# ...

# %%
input_data = pd.read_csv('../data/train/input_2023_w01.csv')
input_data.head()
# Out:
#       game_id  play_id  player_to_predict  nfl_id  frame_id play_direction  \
# 0  2023090700      101              False   54527         1          right
# 1  2023090700      101              False   54527         2          right
# 2  2023090700      101              False   54527         3          right
# 3  2023090700      101              False   54527         4          right
# 4  2023090700      101              False   54527         5          right
#
#    absolute_yardline_number player_name player_height  player_weight  \
# 0                        42  Bryan Cook           6-1            210
# 1                        42  Bryan Cook           6-1            210
# 2                        42  Bryan Cook           6-1            210
# 3                        42  Bryan Cook           6-1            210
# 4                        42  Bryan Cook           6-1            210
#
#   player_birth_date player_position player_side         player_role      x  \
# ...

# %%
output_data = pd.read_csv('../data/train/output_2023_w01.csv')
output_data.head()
# Out:
#       game_id  play_id  nfl_id  frame_id      x      y
# 0  2023090700      101   46137         1  56.22  17.28
# 1  2023090700      101   46137         2  56.63  16.88
# 2  2023090700      101   46137         3  57.06  16.46
# 3  2023090700      101   46137         4  57.48  16.02
# 4  2023090700      101   46137         5  57.91  15.56
